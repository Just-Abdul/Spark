# %% [markdown]
# # A Collaborative Filtering project for Recommender System Using Alternating Least Squares Algorithm(ALS)

# %%
# Importing the necessary libraries

from pyspark.sql import SparkSession
from pyspark.ml.recommendation import ALS
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml.tuning import ParamGridBuilder, CrossValidator
from pyspark.sql.functions import col,explode
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
spark = SparkSession.builder.appName("Project_1").getOrCreate()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Defining the file path

path1 = "/FileStore/tables/movies.csv"
path2 = "/FileStore/tables/ratings.csv"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Reading the CSV file

movies = spark.read.csv(path1, header=True, inferSchema=True)
ratings = spark.read.csv(path2, header=True, inferSchema=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Printing out the dataframe's schema.

movies.printSchema()
ratings.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- movieId: integer (nullable = true)
# -- title: string (nullable = true)
# -- genres: string (nullable = true)
#
# root
# -- userId: integer (nullable = true)
# -- movieId: integer (nullable = true)
# -- rating: double (nullable = true)
# -- timestamp: integer (nullable = true)
#
# </div>

# %%
display(movies)
display(ratings)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>movieId</th><th>title</th><th>genres</th></tr></thead><tbody><tr><td>1</td><td>Toy Story (1995)</td><td>Adventure|Animation|Children|Comedy|Fantasy</td></tr><tr><td>2</td><td>Jumanji (1995)</td><td>Adventure|Children|Fantasy</td></tr><tr><td>3</td><td>Grumpier Old Men (1995)</td><td>Comedy|Romance</td></tr><tr><td>4</td><td>Waiting to Exhale (1995)</td><td>Comedy|Drama|Romance</td></tr><tr><td>5</td><td>Father of the Bride Part II (1995)</td><td>Comedy</td></tr><tr><td>6</td><td>Heat (1995)</td><td>Action|Crime|Thriller</td></tr><tr><td>7</td><td>Sabrina (1995)</td><td>Comedy|Romance</td></tr><tr><td>8</td><td>Tom and Huck (1995)</td><td>Adventure|Children</td></tr><tr><td>9</td><td>Sudden Death (1995)</td><td>Action</td></tr><tr><td>10</td><td>GoldenEye (1995)</td><td>Action|Adventure|Thriller</td></tr><tr><td>11</td><td>American President, The (1995)</td><td>Comedy|Drama|Romance</td></tr><tr><td>12</td><td>Dracula: Dead and Loving It (1995)</td><td>Comedy|Horror</td></tr><tr><td>13</td><td>Balto (1995)</td><td>Adventure|Animation|Children</td></tr><tr><td>14</td><td>Nixon (1995)</td><td>Drama</td></tr><tr><td>15</td><td>Cutthroat Island (1995)</td><td>Action|Adventure|Romance</td></tr><tr><td>16</td><td>Casino (1995)</td><td>Crime|Drama</td></tr><tr><td>17</td><td>Sense and Sensibility (1995)</td><td>Drama|Romance</td></tr><tr><td>18</td><td>Four Rooms (1995)</td><td>Comedy</td></tr><tr><td>19</td><td>Ace Ventura: When Nature Calls (1995)</td><td>Comedy</td></tr><tr><td>20</td><td>Money Train (1995)</td><td>Action|Comedy|Crime|Drama|Thriller</td></tr><tr><td>21</td><td>Get Shorty (1995)</td><td>Comedy|Crime|Thriller</td></tr><tr><td>22</td><td>Copycat (1995)</td><td>Crime|Drama|Horror|Mystery|Thriller</td></tr><tr><td>23</td><td>Assassins (1995)</td><td>Action|Crime|Thriller</td></tr><tr><td>24</td><td>Powder (1995)</td><td>Drama|Sci-Fi</td></tr><tr><td>25</td><td>Leaving Las Vegas (1995)</td><td>Drama|Romance</td></tr><tr><td>26</td><td>Othello (1995)</td><td>Drama</td></tr><tr><td>27</td><td>Now and Then (1995)</td><td>Children|Drama</td></tr><tr><td>28</td><td>Persuasion (1995)</td><td>Drama|Romance</td></tr><tr><td>29</td><td>City of Lost Children, The (Cité des enfants perdus, La) (1995)</td><td>Adventure|Drama|Fantasy|Mystery|Sci-Fi</td></tr><tr><td>30</td><td>Shanghai Triad (Yao a yao yao dao waipo qiao) (1995)</
td>367</td><td>Mask, The (1994)</td><td>Action|Comedy|Crime|Fantasy</td><td>1</td><td>4.0</td><td>964981710</td></tr><tr><td>423</td><td>Blown Away (1994)</td><td>Action|Thriller</td><td>1</td><td>3.0</td><td>964982363</td></tr><tr><td>441</td><td>Dazed and Confused (1993)</td><td>Comedy</td><td>1</td><td>4.0</td><td>964980868</td></tr><tr><td>457</td><td>Fugitive, The (1993)</td><td>Thriller</td><td>1</td><td>5.0</td><td>964981909</td></tr><tr><td>480</td><td>Jurassic Park (1993)</td><td>Action|Adventure|Sci-Fi|Thriller</td><td>1</td><td>4.0</td><td>964982346</td></tr><tr><td>500</td><td>Mrs. Doubtfire (1993)</td><td>Comedy|Drama</td><td>1</td><td>3.0</td><td>964981208</td></tr><tr><td>527</td><td>Schindler's List (1993)</td><td>Drama|War</td><td>1</td><td>5.0</td><td>964984002</td></tr><tr><td>543</td><td>So I Married an Axe Murderer (1993)</td><td>Comedy|Romance|Thriller</td><td>1</td><td>4.0</td><td>964981179</td></tr><tr><td>552</td><td>Three Musketeers, The (1993)</td><td>Action|Adventure|Comedy|Romance</td><td>1</td><td>4.0</td><td>964982653</td></tr><tr><td>553</td><td>Tombstone (1993)</td><td>Action|Dra ...

# %%
# Splitting the data into train and test set (80%:20%)

(train, test) = df.randomSplit([0.8,0.2])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# DataFrame size, Train size, Test size

print("Dataframe size : " + str(df.count()))
print("Train size : " + str(train.count()))
print("Test size : " + str(test.count()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Dataframe size : 100836
# Train size : 80653
# Test size : 20183
# </div>

# %%
# Building the recommendation model using ALS Algorithm on the training data

als = ALS(implicitPrefs= False, coldStartStrategy="drop", nonnegative=True , itemCol= 'movieId', userCol= 'userId' , ratingCol= 'rating')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# ParamGridBuilder to construct a grid of parameters to search over.

param_grid = ParamGridBuilder() \
            .addGrid(als.rank, [10, 50, 100, 150]) \
            .addGrid(als.regParam, [.01, .05, .1, .15]) \
            .build()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Metric to measure how well the model performs on the test data (Root Mean Square Error)

evaluator = RegressionEvaluator(
           metricName="rmse", 
           labelCol="rating", 
           predictionCol="prediction")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Cross-validation for model performance measurement

cv = CrossValidator(estimator=als, estimatorParamMaps=param_grid, evaluator=evaluator, numFolds=5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Training the model

model = cv.fit(train)
best_model = model.bestModel
test_predictions = best_model.transform(test)
RMSE = evaluator.evaluate(test_predictions)
print(RMSE)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/spark/python/pyspark/ml/util.py:838: UserWarning: Cannot find mlflow module. To enable MLflow logging, install mlflow from PyPI.
#   warnings.warn(_MLflowInstrumentation._NO_MLFLOW_WARNING)
# 0.8722439257644753
# </div>

# %%
# The root mean squared error (RMSE) to measure error of the model

print(RMSE)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">0.8722439257644753
# </div>

# %%
# Recommendation based on the model

top_recommendations = best_model.recommendForAllUsers(3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(top_recommendations)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>userId</th><th>recommendations</th></tr></thead><tbody><tr><td>1</td><td>List(List(3379, 5.6086335), List(33649, 5.572328), List(132333, 5.542776))</td></tr><tr><td>2</td><td>List(List(33649, 4.6531262), List(3379, 4.6301174), List(74282, 4.5470786))</td></tr><tr><td>3</td><td>List(List(6835, 4.85197), List(5746, 4.85197), List(70946, 4.8093114))</td></tr><tr><td>4</td><td>List(List(4765, 4.7654986), List(25825, 4.7471814), List(1046, 4.7145658))</td></tr><tr><td>5</td><td>List(List(3379, 4.4748516), List(132333, 4.453083), List(5490, 4.453083))</td></tr><tr><td>6</td><td>List(List(33649, 4.794703), List(74282, 4.7539625), List(67618, 4.714146))</td></tr><tr><td>7</td><td>List(List(6818, 4.7023034), List(3379, 4.698065), List(92494, 4.5171165))</td></tr><tr><td>8</td><td>List(List(3379, 4.770545), List(33649, 4.5892406), List(6818, 4.561652))</td></tr><tr><td>9</td><td>List(List(3379, 4.594421), List(6818, 4.5482078), List(33649, 4.5370383))</td></tr><tr><td>10</td><td>List(List(71579, 4.4729085), List(8869, 4.354601), List(113275, 4.3501625))</td></tr><tr><td>11</td><td>List(List(3379, 5.0761085), List(59018, 4.8276024), List(60943, 4.8276024))</td></tr><tr><td>12</td><td>List(List(67618, 5.5760484), List(77846, 5.5500374), List(93008, 5.5500374))</td></tr><tr><td>13</td><td>List(List(3379, 5.0239615), List(33649, 5.0079203), List(7841, 4.941648))</td></tr><tr><td>14</td><td>List(List(2563, 4.4589906), List(1279, 4.456422), List(6818, 4.4362874))</td></tr><tr><td>15</td><td>List(List(60943, 4.465097), List(7841, 4.465097), List(59018, 4.465097))</td></tr><tr><td>16</td><td>List(List(3379, 4.4951124), List(6818, 4.233386), List(33649, 4.2213407))</td></tr><tr><td>17</td><td>List(List(3379, 5.1171036), List(33649, 4.9156833), List(5490, 4.8172026))</td></tr><tr><td>18</td><td>List(List(3379, 4.965103), List(33649, 4.7359257), List(171495, 4.6820745))</td></tr><tr><td>19</td><td>List(List(3379, 4.013867), List(33649, 3.9255555), List(26326, 3.859996))</td></tr><tr><td>20</td><td>List(List(8542, 4.9098196), List(5490, 4.9098196), List(132333, 4.9098196))</td></tr><tr><td>21</td><td>List(List(67618, 4.6029353), List(3086, 4.535093), List(41724, 4.1426415))</td></tr><tr><td>22</td><td>List(List(1952, 4.106236), List(213, 4.043685), List(68536, 3.877367))</td></tr><tr><td>23</td><td>List(List(3379, 4.452235), List(59018, 4.1701765), List(7841, 4.1701765))</td></tr><tr><td>24</td><td>List(List(3379, 4.7319393), List(33649, 4.5206723), List(171495, 4.4679985))</td></tr><tr><td>25</td><td>List(List(3379, 5.7497406), List(33649, 5.6219206), List(171495, 5.4632087))</td></tr><tr><td>26</td><td>List(List(3379, 4.3907785), List(33649, 4.3027873), List(171495, 4.193356))</td></tr><tr><td>27</td><td>List(List(3451, 4.5945864), List(33649, 4.566546), List(5867, 4.487266))</td></tr><tr><td>28</td><td>List(List(60943, 4.2659197), List(7841, 4.2659197), List(59018, 4.2659197))</td></tr><tr><td>29</td><td>List(List(3379, 5.3080945), List(171495, 4.914389), List(33649, 4.881058))</td></tr><tr><td>30</td><td>List(List(33649, 5.654168), List(3379, 5.542922), List(67618, 5.5296783))</td></tr><tr><td>31</td><td>List(List(33649, 5.1065288), List(3379, 4.962131), List(67618, 4.838869))</td></tr><tr><td>32</td><td>List(List(3379, 5.055652), List(33649, 4.9651113), List(4495, 4.9154787))</td></tr><tr><td>33</td><td>List(List(1545, 4.82855), List(3379, 4.750997), List(5490, 4.70172))</td></tr><tr><td>34</td><td>List(List(67618, 4.446361), List(33649, 4.3742056), List(183897, 4.346957))</td></tr><tr><td>35</td><td>List(List(3379, 5.2594733), List(132333, 5.121527), List(5490, 5.121527))</td></tr><tr><td>36</td><td>List(List(3347, 3.6908317), List(51931, 3.5656424), List(26171, 3.447738))</td></tr><tr><td>37</td><td>List(List(3379, 5.506355), List(171495, 5.135334), List(33649, 5.117371))</td></tr><tr><td>38</td><td>List(List(8542, 4.322085) ...

# %%
# Top recommendation and their ratings

top_rec = top_recommendations.withColumn("movieid_rating", explode("recommendations"))
display(top_rec)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>userId</th><th>recommendations</th><th>movieid_rating</th></tr></thead><tbody><tr><td>1</td><td>List(List(3379, 5.6086335), List(33649, 5.572328), List(5490, 5.542776))</td><td>List(3379, 5.6086335)</td></tr><tr><td>1</td><td>List(List(3379, 5.6086335), List(33649, 5.572328), List(5490, 5.542776))</td><td>List(33649, 5.572328)</td></tr><tr><td>1</td><td>List(List(3379, 5.6086335), List(33649, 5.572328), List(5490, 5.542776))</td><td>List(5490, 5.542776)</td></tr><tr><td>2</td><td>List(List(33649, 4.6531262), List(3379, 4.6301174), List(74282, 4.5470786))</td><td>List(33649, 4.6531262)</td></tr><tr><td>2</td><td>List(List(33649, 4.6531262), List(3379, 4.6301174), List(74282, 4.5470786))</td><td>List(3379, 4.6301174)</td></tr><tr><td>2</td><td>List(List(33649, 4.6531262), List(3379, 4.6301174), List(74282, 4.5470786))</td><td>List(74282, 4.5470786)</td></tr><tr><td>3</td><td>List(List(5746, 4.85197), List(6835, 4.85197), List(70946, 4.8093114))</td><td>List(5746, 4.85197)</td></tr><tr><td>3</td><td>List(List(5746, 4.85197), List(6835, 4.85197), List(70946, 4.8093114))</td><td>List(6835, 4.85197)</td></tr><tr><td>3</td><td>List(List(5746, 4.85197), List(6835, 4.85197), List(70946, 4.8093114))</td><td>List(70946, 4.8093114)</td></tr><tr><td>4</td><td>List(List(4765, 4.7654986), List(25825, 4.7471814), List(1046, 4.7145658))</td><td>List(4765, 4.7654986)</td></tr><tr><td>4</td><td>List(List(4765, 4.7654986), List(25825, 4.7471814), List(1046, 4.7145658))</td><td>List(25825, 4.7471814)</td></tr><tr><td>4</td><td>List(List(4765, 4.7654986), List(25825, 4.7471814), List(1046, 4.7145658))</td><td>List(1046, 4.7145658)</td></tr><tr><td>5</td><td>List(List(3379, 4.4748516), List(132333, 4.453083), List(5490, 4.453083))</td><td>List(3379, 4.4748516)</td></tr><tr><td>5</td><td>List(List(3379, 4.4748516), List(132333, 4.453083), List(5490, 4.453083))</td><td>List(132333, 4.453083)</td></tr><tr><td>5</td><td>List(List(3379, 4.4748516), List(132333, 4.453083), List(5490, 4.453083))</td><td>List(5490, 4.453083)</td></tr><tr><td>6</td><td>List(List(33649, 4.794703), List(74282, 4.7539625), List(67618, 4.714146))</td><td>List(33649, 4.794703)</td></tr><tr><td>6</td><td>List(List(33649, 4.794703), List(74282, 4.7539625), List(67618, 4.714146))</td><td>List(74282, 4.7539625)</td></tr><tr><td>6</td><td>List(List(33649, 4.794703), List(74282, 4.7539625), List(67618, 4.714146))</td><td>List(67618, 4.714146)</td></tr><tr><td>7</td><td>List(List(6818, 4.7023034), List(3379, 4.698065), List(92494, 4.5171165))</td><td>List(6818, 4.7023034)</td></tr><tr><td>7</td><td>List(List(6818, 4.7023034), List(3379, 4.698065), List(92494, 4.5171165))</td><td>List(3379, 4.698065)</td></tr><tr><td>7</td><td>List(List(6818, 4.7023034), List(3379, 4.698065), List(92494, 4.5171165))</td><td>List(92494, 4.5171165)</td></tr><tr><td>8</td><td>List(List(3379, 4.770545), List(33649, 4.5892406), List(6818, 4.561652))</td><td>List(3379, 4.770545)</td></tr><tr><td>8</td><td>List(List(3379, 4.770545), List(33649, 4.5892406), List(6818, 4.561652))</td><td>List(33649, 4.5892406)</td></tr><tr><td>8</td><td>List(List(3379, 4.770545), List(33649, 4.5892406), List(6818, 4.561652))</td><td>List(6818, 4.561652)</td></tr><tr><td>9</td><td>List(List(3379, 4.594421), List(6818, 4.5482078), List(33649, 4.5370383))</td><td>List(3379, 4.594421)</td></tr><tr><td>9</td><td>List(List(3379, 4.594421), List(6818, 4.5482078), List(33649, 4.5370383))</td><td>List(6818, 4.5482078)</td></tr><tr><td>9</td><td>List(List(3379, 4.594421), List(6818, 4.5482078), List(33649, 4.5370383))</td><td>List(33649, 4.5370383)</td></tr><tr><td>10</td><td>List(List(71579, 4.4729085), List(8869, 4.354601), List(113275, 4.3501625))</td><td>List(71579, 4.4729085)</td></tr><tr><td>10</td><td>List(List(71579, 4.4729085), List(8869, 4.354601), List(113275, 4.3501625))</td><td>List(8869, 4.354601)</td></tr><t ...

# %%
# Each user movie recommendation

user_rec = display(top_rec.select("userId", col("movieid_rating.movieId"), col("movieid_rating.rating")))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>userId</th><th>movieId</th><th>rating</th></tr></thead><tbody><tr><td>1</td><td>3379</td><td>5.6086335</td></tr><tr><td>1</td><td>33649</td><td>5.572328</td></tr><tr><td>1</td><td>8542</td><td>5.542776</td></tr><tr><td>2</td><td>33649</td><td>4.6531262</td></tr><tr><td>2</td><td>3379</td><td>4.6301174</td></tr><tr><td>2</td><td>74282</td><td>4.5470786</td></tr><tr><td>3</td><td>6835</td><td>4.85197</td></tr><tr><td>3</td><td>5746</td><td>4.85197</td></tr><tr><td>3</td><td>70946</td><td>4.8093114</td></tr><tr><td>4</td><td>4765</td><td>4.7654986</td></tr><tr><td>4</td><td>25825</td><td>4.7471814</td></tr><tr><td>4</td><td>1046</td><td>4.7145658</td></tr><tr><td>5</td><td>3379</td><td>4.4748516</td></tr><tr><td>5</td><td>132333</td><td>4.453083</td></tr><tr><td>5</td><td>5490</td><td>4.453083</td></tr><tr><td>6</td><td>33649</td><td>4.794703</td></tr><tr><td>6</td><td>74282</td><td>4.7539625</td></tr><tr><td>6</td><td>67618</td><td>4.714146</td></tr><tr><td>7</td><td>6818</td><td>4.7023034</td></tr><tr><td>7</td><td>3379</td><td>4.698065</td></tr><tr><td>7</td><td>92494</td><td>4.5171165</td></tr><t